# %% [markdown]
# CHAD write about what this is

# %% [markdown]
# Questions
# <br>1) Association of El Nino ONI on precipitation in the Sacremento region. </br>
# <br>2) Association of El Nino ONI on temperture in the Sacremnto region.</br>
# <br>3) Association of El NIno ONI on the water temperture off the cost of El Nino.</br>

# %%
import requests
import requests_ftp
import requests_cache
import urllib2
from bs4 import BeautifulSoup
import re
import itertools
import pandas as pd
import numpy as np

# %%
url = "http://www.cpc.ncep.noaa.gov/products/analysis_monitoring/ensostuff/ensoyears.shtml"
ONI_req = requests.get(url) #Ping the server
ONI_html = aggie_req.text #Obtain the text file of the webstie
ONI = BeautifulSoup(aggie_html, 'lxml') #Change to html code
ONI_data = ONI.findAll('table',{'border':"1"})[0]
ONI_data
# Out:
# <table border="1" cellpadding="0" cellspacing="0">\n<tr><!-- Headings -->\n<td width="7%">\n<p align="center"><font face="verdana,arial" size="2"><strong>Year</strong></font></p>\n</td>\n<td width="7%">\n<p align="center"><font face="verdana,arial" size="2"><strong>DJF</strong></font></p>\n</td>\n<td width="7%">\n<p align="center"><font face="verdana,arial" size="2"><strong>JFM</strong></font></p>\n</td>\n<td width="7%">\n<p align="center"><font face="verdana,arial" size="2"><strong>FMA</strong></font></p>\n</td>\n<td width="7%">\n<p align="center"><font face="verdana,arial" size="2"><strong>MAM</strong></font></p>\n</td>\n<td width="7%">\n<p align="center"><font face="verdana,arial" size="2"><strong>AMJ</strong></font></p>\n</td>\n<td width="7%">\n<p align="center"><font face="verdana,arial" size="2"><strong>MJJ</strong></font></p>\n</td>\n<td width="7%">\n<p align="center"><font face="verdana,arial" size="2"><strong>JJA</strong></font></p>\n</td>\n<td width="7%">\n<p align="center"
# ...

# %%
test = ONI_data.findAll('td', {'width':'7%'})
data = []
for i in test:
    value = str(i.text).strip("\n")
    if re.search("[A-z]", value, re.IGNORECASE) == None:
        data.append(value)
subList = [data[n:n+13] for n in range(0, len(data), 13)]
col = ["Year", "Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
data_complete = pd.DataFrame(subList, columns = col)
data_complete = data_complete.set_index("Year")
data_complete
# Out:
#        Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# Year
# 1950  -1.4  -1.2  -1.1  -1.2  -1.1  -0.9  -0.6  -0.6  -0.5  -0.6  -0.7  -0.8
# 1951  -0.8  -0.6  -0.2   0.2   0.2   0.4   0.5   0.7   0.8   0.9   0.7   0.6
# 1952   0.5   0.4   0.4   0.4   0.4   0.2     0   0.1   0.2   0.2   0.2   0.3
# 1953   0.5   0.6   0.7   0.7   0.7   0.7   0.7   0.7   0.8   0.8   0.8   0.7
# 1954   0.7   0.4     0  -0.4  -0.5  -0.5  -0.5  -0.7  -0.7  -0.6  -0.5  -0.5
# 1955  -0.6  -0.6  -0.7  -0.7  -0.7  -0.6  -0.6  -0.6  -1.0  -1.4  -1.6  -1.4
# 1956  -0.9  -0.6  -0.6  -0.5  -0.5  -0.4  -0.5  -0.5  -0.4  -0.4  -0.5  -0.4
# 1957  -0.3     0   0.3   0.6   0.7   0.9   1.0   1.2   1.1   1.2   1.3   1.6
# 1958   1.7   1.5   1.2   0.8   0.7   0.6   0.5   0.4   0.4   0.5   0.6   0.6
# 1959   0.6   0.5   0.4   0.2   0.1  -0.2  -0.3  -0.3  -0.1  -0.1  -0.1  -0.1
# 1960  -0.1  -0.2  -0.1     0  -0.1  -0.2     0   0.1   0.2   0.1     0     0
# ...
